# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import utils
import pandas as pd
import gc
import mlrose_hiive as mlrose

from mlrose_hiive.algorithms.decay import ExpDecay
from mlrose_hiive.neural import NeuralNetwork

from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    END = '\033[0m'

# %%
#stratified sampling in sklearn
def stratified_sampling(vegito, target, size = 0.4, seed = 903949505):
    gc.collect()
    goku, vegita = train_test_split(vegito, test_size=size, stratify=vegito[target], random_state=seed)
    print(color.BOLD + color.UNDERLINE + color.DARKCYAN + "Original distribution" + color.END)
    c = vegito[target].value_counts(normalize=False)
    p = vegito[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.WARNING + "Train distribution" + color.END)
    c = goku[target].value_counts(normalize=False)
    p = goku[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.RED + "Test distribution" + color.END)
    c = vegita[target].value_counts(normalize=False)
    p = vegita[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    
    #split goku, vegita and cell by target variable to make depent and indepent data seperately
    goku_X = goku.drop(target, axis=1)
    vegita_X = vegita.drop(target, axis=1)
    goku_y = pd.DataFrame(goku[target])
    vegita_y = pd.DataFrame(vegita[target])
    
    #return goku_X, goku_y, vegita_X, vegita_y
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_x shape" + color.END)
    print("Number of columns are " + color.BOLD + str(goku_X.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(goku_X.shape[1]) + color.END)
    display(goku_X.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_y shape" + color.END)
    print("Number of columns are " + color.BOLD + str(goku_y.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(goku_y.shape[1]) + color.END)
    display(goku_y.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_x shape" + color.END)
    print("Number of columns are " + color.BOLD + str(vegita_X.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(vegita_X.shape[1]) + color.END)
    display(vegita_X.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_y shape" + color.END)
    print("Number of columns are " + color.BOLD + str(vegita_y.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(vegita_y.shape[1]) + color.END)
    display(vegita_y.head())
    return goku_X, goku_y, vegita_X, vegita_y

# %%
def plot_nn_perf(trainX, testX, trainY, testY, random_seeds, **kwargs):
    
    gc.collect()
    # Initialize algorithms, corresponding acronyms and max number of iterations
    algorithms = ['random_hill_climb', 'simulated_annealing', 'genetic_alg', 'gradient_descent']
    max_iters = ['rhc_max_iters', 'sa_max_iters', 'ga_max_iters', 'gd_max_iters']

    # Define SA exponential decay schedule
    exp_decay = ExpDecay(init_temp=kwargs['init_temp'],
                         exp_const=kwargs['exp_decay_rate'],
                         min_temp=kwargs['min_temp'])

    Output = pd.DataFrame(columns=['i', 'algorithm', 'random_seed', 'Itterations', 'train_accuracy', 'val_acccuracy', 'train_times', 'test_accuracy', 'test_F1'])
    
    # For each of the optimization algorithms to test the Neural Network with
    for i, algorithm in enumerate(algorithms):
        gc.collect()
        print('\nAlgorithm = {}'.format(algorithm))

        # Initialize training losses, validation losses and training time lists for current random run
        for random_seed in random_seeds:
            
            gc.collect()
            # Compute stratified k-fold
            x_train_fold, x_val_fold, y_train_fold, y_val_fold = train_test_split(trainX, trainY, test_size=0.2, shuffle=False,random_state=random_seed, stratify=trainY)
            
            # For each max iterations to run for
            for max_iter in kwargs[max_iters[i]]:

                # Define Neural Network using current algorithm
                nn = NeuralNetwork(hidden_nodes=[32,], activation='relu',
                                   algorithm=algorithm, max_iters=int(max_iter),
                                   bias=True, is_classifier=True, learning_rate=0.001,
                                   early_stopping=False, clip_max=1e10, schedule=exp_decay,
                                   pop_size=kwargs['pop_size'], mutation_prob=kwargs['mutation_prob'],
                                   max_attempts=int(max_iter), random_state=random_seed, curve=True)

                # Train on current training fold and append training time
                start_time = time.time()
                nn.fit(x_train_fold, y_train_fold)
                train_times = time.time() - start_time
                
                # Compute and append training and validation log losses
                train_accuracy = accuracy_score(y_train_fold, pd.DataFrame(nn.predict(x_train_fold), index=y_train_fold.index))
                val_acccuracy = accuracy_score(y_val_fold, pd.DataFrame(nn.predict(x_val_fold), index=y_val_fold.index))
                test_acccuracy = accuracy_score(testY, pd.DataFrame(nn.predict(testX), index=testY.index))
                test_f1_score = f1_score(testY, pd.DataFrame(nn.predict(testX), index=testY.index))
                
                print('{} - train loss = {:.3f}, val loss = {:.3f}'.format(max_iter, train_accuracy, val_acccuracy))
                Output = Output.append({'i' : i, 'algorithm' : algorithm, 'random_seed' : random_seed, 'Itterations' : max_iter, 'train_accuracy' : train_accuracy, 'val_acccuracy' : val_acccuracy, 'train_times' : train_times, 'test_accuracy' : test_acccuracy, 'test_F1' : test_f1_score}, ignore_index=True)
            display(Output)
                
    return Output

# %%
def neural_network(trainX, testX, trainY, testY):
    # Maximum iterations to run the Neural Network for
#     iterations = np.arange(1000, 10001, 1000)
    iterations = np.arange(5, 301, 5)
#     random_seeds = np.array([7, 123, 10000, 99999])
    random_seeds = np.array([7, 123, 10000])

    # Plot performances for RHC, SA, GA and GD with Neural Networks
    Output = plot_nn_perf(trainX, testX, trainY, testY,
                            random_seeds=random_seeds,
                            rhc_max_iters=iterations, sa_max_iters=iterations,
                            ga_max_iters=iterations, gd_max_iters=iterations,
                            init_temp=100, exp_decay_rate=0.1, min_temp=0.001,
                            pop_size=100, mutation_prob=0.2)
    return Output

# %%
data = pd.read_csv("C:/Users/sagni/Documents/Personal Files/CS7641/CS7641/Data/Self_generated/Generated_data.csv")
trainX, trainY, testX, testY = stratified_sampling(data, 'target', 0.8, 903949505)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(trainX)
trainX = pd.DataFrame(scaler.transform(trainX), columns=trainX.columns, index=trainX.index)
testX = pd.DataFrame(scaler.transform(testX), columns=testX.columns, index=testX.index)
display(trainX.head())
display(testX.head())
# Out:
# Original distribution
#    counts      %
# 0    7645  76.45
# 1    2355  23.55
# Train distribution
#    counts      %
# 0    1529  76.45
# 1     471  23.55
# Test distribution
#    counts      %
# 0    6116  76.45
# 1    1884  23.55
# Train_x shape
# Number of columns are 2000 and number of rows are 145
#        feature_1   feature_2    feature_3   feature_4   feature_5   feature_6  \
# 4853 -142.906604  -87.116631  1447.182780  263.891100   22.647175  101.785843
# 1300 -131.354753 -255.451450  -202.951092  279.196803   34.621199 -539.293988
# 4254  -13.134527  -55.191820  3452.084670  -43.316761  281.410370  782.138216
# 9418 -466.245407 -833.500970  3327.754776  -80.851435  178.505091   37.608431
# 2238  223.911099  267.935274  -628.670161 -201.998881 -441.654039 -791.040918
# 500 - train loss = 0.236, val loss = 0.241
# 600 - train loss = 0.533, val loss = 0.547
# 700 - train loss = 0.235, val loss = 0.236
# 800 - train loss = 0.235, val loss = 0.236
# 900 - train loss = 0.633, val loss = 0.628
# 1000 - train loss = 0.457, val loss = 0.464
#    i          algorithm random_seed Itterations  train_accuracy  \
# 0  0  random_hill_climb           7         100        0.244375
# 1  0  random_hill_climb           7         200        0.764583
# 2  0  random_hill_climb           7         300        0.238542
# 3  0  random_hill_climb           7         400        0.235417
# 4  0  random_hill_climb           7         500        0.235833
# 5  0  random_hill_climb           7         600        0.532917
# 6  0  random_hill_climb           7         700        0.235417
# 7  0  random_hill_climb           7         800        0.235417
# 8  0  random_hill_climb           7         900        0.633333
# 9  0  random_hill_climb           7        1000        0.457083
#
#    val_acccuracy  train_times  test_accuracy   test_F1
# 0       0.247500     0.785479        0.24475  0.041865
# 1       0.764167     1.577356        0.76450  0.866534
# 2       0.239167     2.386470        0.23875  0.009756
# 3       0.235833     1.924103        0.23550  0.000000
# 4       0.240833     4.151412        0.23550  0.000654
# 5       0.546667     5.760213        0.54650  0.663326
# 6       0.235833     5.268932        0.23575  0.000654
# 7       0.235833     6.146974        0.23550  0.000000
# 8       0.628333     6.957041        0.61650  0.747115
# 9       0.464167     7.962209        0.46850  0.559652
# 100 - train loss = 0.765, val loss = 0.764
# 200 - train loss = 0.764, val loss = 0.765
# 300 - train loss = 0.759, val loss = 0.757
# 400 - train loss = 0.764, val loss = 0.762
# 500 - train loss = 0.238, val loss = 0.238
# 600 - train loss = 0.764, val loss = 0.764
# 700 - train loss = 0.260, val loss = 0.255
# 800 - train loss = 0.235, val loss = 0.236
# 900 - train loss = 0.297, val loss = 0.298
# 1000 - train loss = 0.718, val loss = 0.711
#     i          algorithm random_seed Itterations  train_accuracy  \
# 0   0  random_hill_climb           7         100        0.244375
# 1   0  random_hill_climb           7         200        0.764583
# 2   0  random_hill_climb           7         300        0.238542
# 3   0  random_hill_climb           7         400        0.235417
# 4   0  random_hill_climb           7         500        0.235833
# 5   0  random_hill_climb           7         600        0.532917
# 6   0  random_hill_climb           7         700        0.235417
# 7   0  random_hill_climb           7         800        0.235417
# 8   0  random_hill_climb           7         900        0.633333
# 9   0  random_hill_climb           7        1000        0.457083
# 10  0  random_hill_climb         123         100        0.764583
# 11  0  random_hill_climb         123         200        0.763958
# 12  0  random_hill_climb         123         300        0.759167
# 13  0  random_hill_climb         123         400        0.764167
# 14  0  random_hill_climb         123         500        0.237708
# 15  0  random_hill_climb         123         600        0.764375
# 16  0  random_hill_climb         123         700        0.259583
# 17  0  random_hill_climb         123         800        0.235417
# 18  0  random_hill_climb         123         900        0.296875
# 19  0  random_hill_climb         123        1000        0.718333
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# 5        0.546667     5.760213        0.54650  0.663326
# 10       0.764167     0.848588        0.76450  0.866534
# 11       0.765000     1.572107        0.76500  0.866667
# 12       0.757500     2.307092        0.75250  0.858329
# 13       0.761667     3.102744        0.76425  0.866298
# 14       0.238333     3.821770        0.23875  0.018059
# 15       0.764167     4.663046        0.76425  0.866374
# 16       0.255000     5.121596        0.25575  0.088208
# 17       0.235833     6.145656        0.23550  0.000000
# 18       0.298333     7.214390        0.31825  0.255528
# 19       0.710833     7.192653        0.71750  0.829099
# 20       0.764167     0.773466        0.76450  0.866534
# 21       0.764167     1.489670        0.76450  0.866497
# 22       0.764167     2.086421        0.76150  0.864450
# 23       0.764167     2.981452        0.76450  0.866534
# 24       0.235833     3.791745        0.23550  0.000000
# 25       0.764167     4.629927        0.76400  0.866213
# 26       0.235833     5.399992        0.23550  0.000000
# 27       0.764167     6.009534        0.76450  0.866534
# 28       0.236667     6.837352        0.23550  0.000000
# 29       0.731667     7.889137        0.72850  0.841367
# Algorithm = simulated_annealing
# 100 - train loss = 0.372, val loss = 0.407
# 200 - train loss = 0.687, val loss = 0.698
# 300 - train loss = 0.281, val loss = 0.292
# 400 - train loss = 0.255, val loss = 0.267
# 500 - train loss = 0.237, val loss = 0.237
# 600 - train loss = 0.750, val loss = 0.744
# 700 - train loss = 0.702, val loss = 0.696
# 800 - train loss = 0.235, val loss = 0.236
# 900 - train loss = 0.237, val loss = 0.237
# 1000 - train loss = 0.561, val loss = 0.572
#     i            algorithm random_seed Itterations  train_accuracy  \
# 0   0    random_hill_climb           7         100        0.244375
# 1   0    random_hill_climb           7         200        0.764583
# 2   0    random_hill_climb           7         300        0.238542
# 3   0    random_hill_climb           7         400        0.235417
# 4   0    random_hill_climb           7         500        0.235833
# 5   0    random_hill_climb           7         600        0.532917
# 6   0    random_hill_climb           7         700        0.235417
# 7   0    random_hill_climb           7         800        0.235417
# 8   0    random_hill_climb           7         900        0.633333
# 9   0    random_hill_climb           7        1000        0.457083
# 10  0    random_hill_climb         123         100        0.764583
# 11  0    random_hill_climb         123         200        0.763958
# 12  0    random_hill_climb         123         300        0.759167
# 13  0    random_hill_climb         123         400        0.764167
# 14  0    random_hill_climb         123         500        0.237708
# 15  0    random_hill_climb         123         600        0.764375
# 16  0    random_hill_climb         123         700        0.259583
# 17  0    random_hill_climb         123         800        0.235417
# 18  0    random_hill_climb         123         900        0.296875
# 19  0    random_hill_climb         123        1000        0.718333
# 20  0    random_hill_climb       10000         100        0.764583
# 21  0    random_hill_climb       10000         200        0.764583
# 22  0    random_hill_climb       10000         300        0.762708
# 23  0    random_hill_climb       10000         400        0.764583
# 24  0    random_hill_climb       10000         500        0.235417
# 25  0    random_hill_climb       10000         600        0.764792
# 26  0    random_hill_climb       10000         700        0.235417
# 27  0    random_hill_climb       10000         800        0.764583
# 28  0    random_hill_climb       10000         900        0.235417
# 29  0    random_hill_climb       10000        1000        0.735833
# 30  1  simulated_annealing           7         100        0.372083
# 31  1  simulated_annealing           7         200        0.687083
# 32  1  simulated_annealing           7         300        0.281250
# 33  1  simulated_annealing           7         400        0.254792
# 34  1  simulated_annealing           7         500        0.236667
# 35  1  simulated_annealing           7         600        0.749583
# 36  1  simulated_annealing           7         700        0.701875
# 37  1  simulated_annealing           7         800        0.235417
# 38  1  simulated_annealing           7         900        0.236875
# 39  1  simulated_annealing           7        1000        0.561250
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# 5        0.546667     5.760213        0.54650  0.663326
# 6        0.235833     5.268932        0.23575  0.000654
# 7        0.235833     6.146974        0.23550  0.000000
# 8        0.628333     6.957041        0.61650  0.747115
# 9        0.464167     7.962209        0.46850  0.559652
# 10       0.764167     0.848588        0.76450  0.866534
# 11       0.765000     1.572107        0.76500  0.866667
# 12       0.757500     2.307092        0.75250  0.858329
# 13       0.761667     3.102744        0.76425  0.866298
# 14       0.238333     3.821770        0.23875  0.018059
# 15       0.764167     4.663046        0.76425  0.866374
# 16       0.255000     5.121596        0.25575  0.088208
# 17       0.235833     6.145656        0.23550  0.000000
# 18       0.298333     7.214390        0.31825  0.255528
# 19       0.710833     7.192653        0.71750  0.829099
# 20       0.764167     0.773466        0.76450  0.866534
# 21       0.764167     1.489670        0.76450  0.866497
# 22       0.764167     2.086421        0.76150  0.864450
# 23       0.764167     2.981452        0.76450  0.866534
# 24       0.235833     3.791745        0.23550  0.000000
# 25       0.764167     4.629927        0.76400  0.866213
# 26       0.235833     5.399992        0.23550  0.000000
# 27       0.764167     6.009534        0.76450  0.866534
# 28       0.236667     6.837352        0.23550  0.000000
# 29       0.731667     7.889137        0.72850  0.841367
# 30       0.406667     1.126122        0.36450  0.366716
# 31       0.698333     2.245947        0.68775  0.806985
# 32       0.291667     3.316756        0.28525  0.141699
# 33       0.266667     4.264987        0.25350  0.070361
# 34       0.236667     5.414577        0.23600  0.001307
# 35       0.744167     6.604782        0.75275  0.856978
# 36       0.695833     7.787205        0.70625  0.823016
# 37       0.235833     8.795957        0.23550  0.000000
# 38       0.237500     9.655589        0.23600  0.001960
# 39       0.571667    10.976105        0.55800  0.680289
# 100 - train loss = 0.261, val loss = 0.248
# 200 - train loss = 0.762, val loss = 0.758
# 300 - train loss = 0.764, val loss = 0.764
# 400 - train loss = 0.260, val loss = 0.247
# 500 - train loss = 0.235, val loss = 0.236
# 600 - train loss = 0.235, val loss = 0.236
# 700 - train loss = 0.564, val loss = 0.582
# 800 - train loss = 0.727, val loss = 0.733
# 900 - train loss = 0.271, val loss = 0.284
# 1000 - train loss = 0.765, val loss = 0.764
#     i            algorithm random_seed Itterations  train_accuracy  \
# 0   0    random_hill_climb           7         100        0.244375
# 1   0    random_hill_climb           7         200        0.764583
# 2   0    random_hill_climb           7         300        0.238542
# 3   0    random_hill_climb           7         400        0.235417
# 4   0    random_hill_climb           7         500        0.235833
# 5   0    random_hill_climb           7         600        0.532917
# 6   0    random_hill_climb           7         700        0.235417
# 7   0    random_hill_climb           7         800        0.235417
# 8   0    random_hill_climb           7         900        0.633333
# 9   0    random_hill_climb           7        1000        0.457083
# 10  0    random_hill_climb         123         100        0.764583
# 11  0    random_hill_climb         123         200        0.763958
# 12  0    random_hill_climb         123         300        0.759167
# 13  0    random_hill_climb         123         400        0.764167
# 14  0    random_hill_climb         123         500        0.237708
# 15  0    random_hill_climb         123         600        0.764375
# 16  0    random_hill_climb         123         700        0.259583
# 17  0    random_hill_climb         123         800        0.235417
# 18  0    random_hill_climb         123         900        0.296875
# 19  0    random_hill_climb         123        1000        0.718333
# 20  0    random_hill_climb       10000         100        0.764583
# 21  0    random_hill_climb       10000         200        0.764583
# 22  0    random_hill_climb       10000         300        0.762708
# 23  0    random_hill_climb       10000         400        0.764583
# 24  0    random_hill_climb       10000         500        0.235417
# 25  0    random_hill_climb       10000         600        0.764792
# 26  0    random_hill_climb       10000         700        0.235417
# 27  0    random_hill_climb       10000         800        0.764583
# 28  0    random_hill_climb       10000         900        0.235417
# 29  0    random_hill_climb       10000        1000        0.735833
# 30  1  simulated_annealing           7         100        0.372083
# 31  1  simulated_annealing           7         200        0.687083
# 32  1  simulated_annealing           7         300        0.281250
# 33  1  simulated_annealing           7         400        0.254792
# 34  1  simulated_annealing           7         500        0.236667
# 35  1  simulated_annealing           7         600        0.749583
# 36  1  simulated_annealing           7         700        0.701875
# 37  1  simulated_annealing           7         800        0.235417
# 38  1  simulated_annealing           7         900        0.236875
# 39  1  simulated_annealing           7        1000        0.561250
# 40  1  simulated_annealing         123         100        0.260625
# 41  1  simulated_annealing         123         200        0.762292
# 42  1  simulated_annealing         123         300        0.764375
# 43  1  simulated_annealing         123         400        0.260000
# 44  1  simulated_annealing         123         500        0.235417
# 45  1  simulated_annealing         123         600        0.235417
# 46  1  simulated_annealing         123         700        0.564375
# 47  1  simulated_annealing         123         800        0.726667
# 48  1  simulated_annealing         123         900        0.271042
# 49  1  simulated_annealing         123        1000        0.764583
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# 5        0.546667     5.760213        0.54650  0.663326
# 6        0.235833     5.268932        0.23575  0.000654
# 7        0.235833     6.146974        0.23550  0.000000
# 8        0.628333     6.957041        0.61650  0.747115
# 9        0.464167     7.962209        0.46850  0.559652
# 10       0.764167     0.848588        0.76450  0.866534
# 11       0.765000     1.572107        0.76500  0.866667
# 12       0.757500     2.307092        0.75250  0.858329
# 13       0.761667     3.102744        0.76425  0.866298
# 14       0.238333     3.821770        0.23875  0.018059
# 15       0.764167     4.663046        0.76425  0.866374
# 16       0.255000     5.121596        0.25575  0.088208
# 17       0.235833     6.145656        0.23550  0.000000
# 18       0.298333     7.214390        0.31825  0.255528
# 19       0.710833     7.192653        0.71750  0.829099
# 20       0.764167     0.773466        0.76450  0.866534
# 21       0.764167     1.489670        0.76450  0.866497
# 22       0.764167     2.086421        0.76150  0.864450
# 23       0.764167     2.981452        0.76450  0.866534
# 24       0.235833     3.791745        0.23550  0.000000
# 25       0.764167     4.629927        0.76400  0.866213
# 26       0.235833     5.399992        0.23550  0.000000
# 27       0.764167     6.009534        0.76450  0.866534
# 28       0.236667     6.837352        0.23550  0.000000
# 29       0.731667     7.889137        0.72850  0.841367
# 30       0.406667     1.126122        0.36450  0.366716
# 31       0.698333     2.245947        0.68775  0.806985
# 32       0.291667     3.316756        0.28525  0.141699
# 33       0.266667     4.264987        0.25350  0.070361
# 34       0.236667     5.414577        0.23600  0.001307
# 35       0.744167     6.604782        0.75275  0.856978
# 36       0.695833     7.787205        0.70625  0.823016
# 37       0.235833     8.795957        0.23550  0.000000
# 38       0.237500     9.655589        0.23600  0.001960
# 39       0.571667    10.976105        0.55800  0.680289
# 40       0.248333     1.075568        0.26300  0.083903
# 41       0.758333     2.089150        0.75975  0.863203
# 42       0.764167     3.323730        0.76450  0.866534
# 43       0.247500     4.495039        0.25125  0.077610
# 44       0.235833     5.590763        0.23550  0.000000
# 45       0.235833     6.357379        0.23550  0.000000
# 46       0.581667     7.854503        0.56450  0.680367
# 47       0.733333     9.105268        0.73400  0.843345
# 48       0.284167     9.860252        0.27300  0.123040
# 49       0.764167    10.492947        0.76450  0.866534
# 100 - train loss = 0.235, val loss = 0.236
# 200 - train loss = 0.743, val loss = 0.740
# 300 - train loss = 0.268, val loss = 0.272
# 400 - train loss = 0.765, val loss = 0.764
# 500 - train loss = 0.739, val loss = 0.738
# 600 - train loss = 0.293, val loss = 0.300
# 700 - train loss = 0.330, val loss = 0.324
# 800 - train loss = 0.235, val loss = 0.236
# 900 - train loss = 0.765, val loss = 0.764
# 1000 - train loss = 0.765, val loss = 0.765
#     i            algorithm random_seed Itterations  train_accuracy  \
# 0   0    random_hill_climb           7         100        0.244375
# 1   0    random_hill_climb           7         200        0.764583
# 2   0    random_hill_climb           7         300        0.238542
# 3   0    random_hill_climb           7         400        0.235417
# 4   0    random_hill_climb           7         500        0.235833
# 5   0    random_hill_climb           7         600        0.532917
# 6   0    random_hill_climb           7         700        0.235417
# 7   0    random_hill_climb           7         800        0.235417
# 8   0    random_hill_climb           7         900        0.633333
# 9   0    random_hill_climb           7        1000        0.457083
# 10  0    random_hill_climb         123         100        0.764583
# 11  0    random_hill_climb         123         200        0.763958
# 12  0    random_hill_climb         123         300        0.759167
# 13  0    random_hill_climb         123         400        0.764167
# 14  0    random_hill_climb         123         500        0.237708
# 15  0    random_hill_climb         123         600        0.764375
# 16  0    random_hill_climb         123         700        0.259583
# 17  0    random_hill_climb         123         800        0.235417
# 18  0    random_hill_climb         123         900        0.296875
# 19  0    random_hill_climb         123        1000        0.718333
# 20  0    random_hill_climb       10000         100        0.764583
# 21  0    random_hill_climb       10000         200        0.764583
# 22  0    random_hill_climb       10000         300        0.762708
# 23  0    random_hill_climb       10000         400        0.764583
# 24  0    random_hill_climb       10000         500        0.235417
# 25  0    random_hill_climb       10000         600        0.764792
# 26  0    random_hill_climb       10000         700        0.235417
# 27  0    random_hill_climb       10000         800        0.764583
# 28  0    random_hill_climb       10000         900        0.235417
# 29  0    random_hill_climb       10000        1000        0.735833
# 30  1  simulated_annealing           7         100        0.372083
# 31  1  simulated_annealing           7         200        0.687083
# 32  1  simulated_annealing           7         300        0.281250
# 33  1  simulated_annealing           7         400        0.254792
# 34  1  simulated_annealing           7         500        0.236667
# 35  1  simulated_annealing           7         600        0.749583
# 36  1  simulated_annealing           7         700        0.701875
# 37  1  simulated_annealing           7         800        0.235417
# 38  1  simulated_annealing           7         900        0.236875
# 39  1  simulated_annealing           7        1000        0.561250
# 40  1  simulated_annealing         123         100        0.260625
# 41  1  simulated_annealing         123         200        0.762292
# 42  1  simulated_annealing         123         300        0.764375
# 43  1  simulated_annealing         123         400        0.260000
# 44  1  simulated_annealing         123         500        0.235417
# 45  1  simulated_annealing         123         600        0.235417
# 46  1  simulated_annealing         123         700        0.564375
# 47  1  simulated_annealing         123         800        0.726667
# 48  1  simulated_annealing         123         900        0.271042
# 49  1  simulated_annealing         123        1000        0.764583
# 50  1  simulated_annealing       10000         100        0.235417
# 51  1  simulated_annealing       10000         200        0.743333
# 52  1  simulated_annealing       10000         300        0.267500
# 53  1  simulated_annealing       10000         400        0.764583
# 54  1  simulated_annealing       10000         500        0.739375
# 55  1  simulated_annealing       10000         600        0.292917
# 56  1  simulated_annealing       10000         700        0.330417
# 57  1  simulated_annealing       10000         800        0.235208
# 58  1  simulated_annealing       10000         900        0.764583
# 59  1  simulated_annealing       10000        1000        0.764583
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# 5        0.546667     5.760213        0.54650  0.663326
# 6        0.235833     5.268932        0.23575  0.000654
# 7        0.235833     6.146974        0.23550  0.000000
# 8        0.628333     6.957041        0.61650  0.747115
# 9        0.464167     7.962209        0.46850  0.559652
# 10       0.764167     0.848588        0.76450  0.866534
# 11       0.765000     1.572107        0.76500  0.866667
# 12       0.757500     2.307092        0.75250  0.858329
# 13       0.761667     3.102744        0.76425  0.866298
# 14       0.238333     3.821770        0.23875  0.018059
# 15       0.764167     4.663046        0.76425  0.866374
# 16       0.255000     5.121596        0.25575  0.088208
# 17       0.235833     6.145656        0.23550  0.000000
# 18       0.298333     7.214390        0.31825  0.255528
# 19       0.710833     7.192653        0.71750  0.829099
# 20       0.764167     0.773466        0.76450  0.866534
# 21       0.764167     1.489670        0.76450  0.866497
# 22       0.764167     2.086421        0.76150  0.864450
# 23       0.764167     2.981452        0.76450  0.866534
# 24       0.235833     3.791745        0.23550  0.000000
# 25       0.764167     4.629927        0.76400  0.866213
# 26       0.235833     5.399992        0.23550  0.000000
# 27       0.764167     6.009534        0.76450  0.866534
# 28       0.236667     6.837352        0.23550  0.000000
# 29       0.731667     7.889137        0.72850  0.841367
# 30       0.406667     1.126122        0.36450  0.366716
# 300 - train loss = 0.766, val loss = 0.766
# 400 - train loss = 0.770, val loss = 0.767
# 500 - train loss = 0.766, val loss = 0.763
# 600 - train loss = 0.768, val loss = 0.762
# 700 - train loss = 0.771, val loss = 0.763
# 800 - train loss = 0.768, val loss = 0.764
# 900 - train loss = 0.768, val loss = 0.763
# 1000 - train loss = 0.768, val loss = 0.758
#     i          algorithm random_seed Itterations  train_accuracy  \
# 0   0  random_hill_climb           7         100        0.244375
# 1   0  random_hill_climb           7         200        0.764583
# 2   0  random_hill_climb           7         300        0.238542
# 3   0  random_hill_climb           7         400        0.235417
# 4   0  random_hill_climb           7         500        0.235833
# .. ..                ...         ...         ...             ...
# 75  2        genetic_alg         123         600        0.767708
# 76  2        genetic_alg         123         700        0.770833
# 77  2        genetic_alg         123         800        0.767708
# 78  2        genetic_alg         123         900        0.767917
# 79  2        genetic_alg         123        1000        0.768125
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# ..            ...          ...            ...       ...
# 75       0.762500   415.637049        0.76500  0.866287
# 76       0.763333   488.118049        0.76775  0.867001
# 77       0.764167   554.658683        0.76700  0.867009
# 78       0.763333   642.075362        0.76150  0.863558
# 79       0.758333   729.867875        0.76550  0.865770
#
# [80 rows x 9 columns]
# 100 - train loss = 0.767, val loss = 0.765
# 200 - train loss = 0.769, val loss = 0.767
# 300 - train loss = 0.766, val loss = 0.765
# 400 - train loss = 0.767, val loss = 0.762
# 500 - train loss = 0.769, val loss = 0.771
# 600 - train loss = 0.766, val loss = 0.759
# 700 - train loss = 0.770, val loss = 0.772
# 800 - train loss = 0.769, val loss = 0.761
# 900 - train loss = 0.768, val loss = 0.760
# 1000 - train loss = 0.770, val loss = 0.760
#     i          algorithm random_seed Itterations  train_accuracy  \
# 0   0  random_hill_climb           7         100        0.244375
# 1   0  random_hill_climb           7         200        0.764583
# 2   0  random_hill_climb           7         300        0.238542
# 3   0  random_hill_climb           7         400        0.235417
# 4   0  random_hill_climb           7         500        0.235833
# .. ..                ...         ...         ...             ...
# 85  2        genetic_alg       10000         600        0.766458
# 86  2        genetic_alg       10000         700        0.769583
# 87  2        genetic_alg       10000         800        0.769167
# 88  2        genetic_alg       10000         900        0.767708
# 89  2        genetic_alg       10000        1000        0.770208
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# ..            ...          ...            ...       ...
# 85       0.759167   420.858233        0.76125  0.863396
# 86       0.771667   487.782809        0.76725  0.867398
# 87       0.760833   554.767013        0.75800  0.859954
# 88       0.760000   627.326891        0.76450  0.865659
# 89       0.760000   697.633087        0.76500  0.864826
#
# [90 rows x 9 columns]
# Algorithm = gradient_descent
# 100 - train loss = 0.735, val loss = 0.730
# 200 - train loss = 0.760, val loss = 0.757
# 300 - train loss = 0.762, val loss = 0.762
# 400 - train loss = 0.235, val loss = 0.237
# 500 - train loss = 0.712, val loss = 0.716
# 600 - train loss = 0.763, val loss = 0.762
# 700 - train loss = 0.474, val loss = 0.478
# 800 - train loss = 0.764, val loss = 0.764
# 900 - train loss = 0.765, val loss = 0.763
# 1000 - train loss = 0.765, val loss = 0.764
#     i          algorithm random_seed Itterations  train_accuracy  \
# 0   0  random_hill_climb           7         100        0.244375
# 1   0  random_hill_climb           7         200        0.764583
# 2   0  random_hill_climb           7         300        0.238542
# 3   0  random_hill_climb           7         400        0.235417
# 4   0  random_hill_climb           7         500        0.235833
# .. ..                ...         ...         ...             ...
# 95  3   gradient_descent           7         600        0.762708
# 96  3   gradient_descent           7         700        0.473750
# 97  3   gradient_descent           7         800        0.764167
# 98  3   gradient_descent           7         900        0.764583
# 99  3   gradient_descent           7        1000        0.764583
#
#     val_acccuracy  train_times  test_accuracy   test_F1
# 0        0.247500     0.785479        0.24475  0.041865
# 1        0.764167     1.577356        0.76450  0.866534
# 2        0.239167     2.386470        0.23875  0.009756
# 3        0.235833     1.924103        0.23550  0.000000
# 4        0.240833     4.151412        0.23550  0.000654
# ..            ...          ...            ...       ...
# 95       0.762500     9.775052        0.76275  0.865218
# 96       0.478333    11.337574        0.48400  0.567114
# 97       0.764167    12.997750        0.76425  0.866374
# 98       0.763333    14.671182        0.76450  0.866497
# 99       0.764167    16.195496        0.76400  0.866213
#
# [100 rows x 9 columns]
# 100 - train loss = 0.764, val loss = 0.764
# 200 - train loss = 0.762, val loss = 0.762
# 300 - train loss = 0.755, val loss = 0.762
# 400 - train loss = 0.764, val loss = 0.767
# 500 - train loss = 0.764, val loss = 0.764
# 600 - train loss = 0.235, val loss = 0.236
# 700 - train loss = 0.627, val loss = 0.629
# 800 - train loss = 0.550, val loss = 0.528
# 900 - train loss = 0.743, val loss = 0.760
# 1000 - train loss = 0.765, val loss = 0.764
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7         100        0.244375
# 1    0  random_hill_climb           7         200        0.764583
# 2    0  random_hill_climb           7         300        0.238542
# 3    0  random_hill_climb           7         400        0.235417
# 4    0  random_hill_climb           7         500        0.235833
# ..  ..                ...         ...         ...             ...
# 105  3   gradient_descent         123         600        0.235417
# 106  3   gradient_descent         123         700        0.626875
# 107  3   gradient_descent         123         800        0.549792
# 108  3   gradient_descent         123         900        0.742708
# 109  3   gradient_descent         123        1000        0.764583
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.247500     0.785479        0.24475  0.041865
# 1         0.764167     1.577356        0.76450  0.866534
# 2         0.239167     2.386470        0.23875  0.009756
# 3         0.235833     1.924103        0.23550  0.000000
# 4         0.240833     4.151412        0.23550  0.000654
# ..             ...          ...            ...       ...
# 105       0.235833     9.761168        0.23550  0.000000
# 106       0.629167    11.468225        0.63475  0.759901
# 107       0.528333    13.040099        0.52550  0.636538
# 108       0.760000    14.667101        0.74925  0.855288
# 109       0.764167    16.322417        0.76450  0.866534
#
# [110 rows x 9 columns]
# 100 - train loss = 0.468, val loss = 0.486
# 200 - train loss = 0.359, val loss = 0.367
# 300 - train loss = 0.724, val loss = 0.716
# 400 - train loss = 0.764, val loss = 0.765
# 500 - train loss = 0.703, val loss = 0.724
# 600 - train loss = 0.764, val loss = 0.764
# 700 - train loss = 0.765, val loss = 0.764
# 800 - train loss = 0.418, val loss = 0.422
# 900 - train loss = 0.746, val loss = 0.735
# 1000 - train loss = 0.764, val loss = 0.763
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7         100        0.244375
# 1    0  random_hill_climb           7         200        0.764583
# 2    0  random_hill_climb           7         300        0.238542
# 3    0  random_hill_climb           7         400        0.235417
# 4    0  random_hill_climb           7         500        0.235833
# ..  ..                ...         ...         ...             ...
# 115  3   gradient_descent       10000         600        0.764375
# 116  3   gradient_descent       10000         700        0.764583
# 117  3   gradient_descent       10000         800        0.418333
# 118  3   gradient_descent       10000         900        0.746042
# 119  3   gradient_descent       10000        1000        0.763958
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.247500     0.785479        0.24475  0.041865
# 1         0.764167     1.577356        0.76450  0.866534
# 2         0.239167     2.386470        0.23875  0.009756
# 3         0.235833     1.924103        0.23550  0.000000
# 4         0.240833     4.151412        0.23550  0.000654
# ..             ...          ...            ...       ...
# 115       0.764167     9.803604        0.76425  0.866374
# 116       0.764167    11.373903        0.76450  0.866534
# 117       0.422500    12.825668        0.41925  0.466835
# 118       0.735000    14.424083        0.73825  0.846818
# 119       0.763333    16.239832        0.76400  0.866175
#
# [120 rows x 9 columns]

# %%
Output = neural_network(trainX, testX, trainY, testY)
output_path = r'C:\Users\sagni\Documents\Personal Files\CS7641\Assignment2\NN_Images\Output_SelfGenerated_2.xlsx'
Output.to_excel(output_path, index=False)
# Out:
# Algorithm = random_hill_climb
# 5 - train loss = 0.258, val loss = 0.253
# 10 - train loss = 0.244, val loss = 0.244
# 15 - train loss = 0.253, val loss = 0.251
# 20 - train loss = 0.720, val loss = 0.713
# 25 - train loss = 0.223, val loss = 0.227
# 30 - train loss = 0.640, val loss = 0.636
# 35 - train loss = 0.759, val loss = 0.759
# 40 - train loss = 0.788, val loss = 0.789
# 45 - train loss = 0.420, val loss = 0.433
# 50 - train loss = 0.648, val loss = 0.645
# 55 - train loss = 0.491, val loss = 0.493
# 60 - train loss = 0.212, val loss = 0.212
# 65 - train loss = 0.715, val loss = 0.706
# 70 - train loss = 0.450, val loss = 0.470
# 75 - train loss = 0.697, val loss = 0.687
# 80 - train loss = 0.463, val loss = 0.454
# 85 - train loss = 0.787, val loss = 0.784
# 90 - train loss = 0.217, val loss = 0.217
# 95 - train loss = 0.224, val loss = 0.227
# 100 - train loss = 0.250, val loss = 0.252
# 105 - train loss = 0.294, val loss = 0.296
# 110 - train loss = 0.212, val loss = 0.211
# 115 - train loss = 0.745, val loss = 0.746
# 120 - train loss = 0.212, val loss = 0.211
# 125 - train loss = 0.212, val loss = 0.211
# 130 - train loss = 0.564, val loss = 0.576
# 135 - train loss = 0.438, val loss = 0.451
# 140 - train loss = 0.260, val loss = 0.260
# 145 - train loss = 0.694, val loss = 0.695
# 150 - train loss = 0.273, val loss = 0.269
# 155 - train loss = 0.732, val loss = 0.716
# 160 - train loss = 0.213, val loss = 0.213
# 165 - train loss = 0.788, val loss = 0.789
# 170 - train loss = 0.785, val loss = 0.782
# 175 - train loss = 0.720, val loss = 0.714
# 180 - train loss = 0.663, val loss = 0.674
# 185 - train loss = 0.531, val loss = 0.553
# 190 - train loss = 0.247, val loss = 0.250
# 195 - train loss = 0.734, val loss = 0.733
# 200 - train loss = 0.733, val loss = 0.723
# 205 - train loss = 0.767, val loss = 0.767
# 210 - train loss = 0.780, val loss = 0.776
# 215 - train loss = 0.292, val loss = 0.293
# 220 - train loss = 0.221, val loss = 0.223
# 225 - train loss = 0.641, val loss = 0.637
# 230 - train loss = 0.654, val loss = 0.654
# 235 - train loss = 0.348, val loss = 0.365
# 240 - train loss = 0.707, val loss = 0.712
# 245 - train loss = 0.762, val loss = 0.763
# 250 - train loss = 0.788, val loss = 0.788
# 255 - train loss = 0.705, val loss = 0.709
# 260 - train loss = 0.680, val loss = 0.685
# 265 - train loss = 0.778, val loss = 0.778
# 270 - train loss = 0.666, val loss = 0.659
# 275 - train loss = 0.668, val loss = 0.667
# 280 - train loss = 0.304, val loss = 0.301
# 285 - train loss = 0.314, val loss = 0.313
# 290 - train loss = 0.603, val loss = 0.602
# 295 - train loss = 0.589, val loss = 0.607
# 300 - train loss = 0.212, val loss = 0.211
#     i          algorithm random_seed Itterations  train_accuracy  \
# 0   0  random_hill_climb           7           5        0.257915
# 1   0  random_hill_climb           7          10        0.244205
# 2   0  random_hill_climb           7          15        0.253371
# 3   0  random_hill_climb           7          20        0.719967
# 4   0  random_hill_climb           7          25        0.222769
# 5   0  random_hill_climb           7          30        0.639979
# 6   0  random_hill_climb           7          35        0.758976
# 7   0  random_hill_climb           7          40        0.788365
# 8   0  random_hill_climb           7          45        0.420391
# 9   0  random_hill_climb           7          50        0.647705
# 10  0  random_hill_climb           7          55        0.491138
# 11  0  random_hill_climb           7          60        0.211786
# 12  0  random_hill_climb           7          65        0.715498
# 13  0  random_hill_climb           7          70        0.449932
# 14  0  random_hill_climb           7          75        0.696788
# 15  0  random_hill_climb           7          80        0.463339
# 16  0  random_hill_climb           7          85        0.786547
# 17  0  random_hill_climb           7          90        0.216710
# 18  0  random_hill_climb           7          95        0.223678
# 19  0  random_hill_climb           7         100        0.249811
# 20  0  random_hill_climb           7         105        0.294425
# 21  0  random_hill_climb           7         110        0.211635
# 22  0  random_hill_climb           7         115        0.744736
# 23  0  random_hill_climb           7         120        0.211635
# 24  0  random_hill_climb           7         125        0.211938
# 25  0  random_hill_climb           7         130        0.564308
# 26  0  random_hill_climb           7         135        0.438191
# 27  0  random_hill_climb           7         140        0.259809
# 28  0  random_hill_climb           7         145        0.693834
# 29  0  random_hill_climb           7         150        0.272762
# 30  0  random_hill_climb           7         155        0.732313
# 31  0  random_hill_climb           7         160        0.212695
# 32  0  random_hill_climb           7         165        0.788365
# 225 - train loss = 0.307, val loss = 0.301
# 230 - train loss = 0.715, val loss = 0.714
# 235 - train loss = 0.379, val loss = 0.381
# 240 - train loss = 0.386, val loss = 0.393
# 245 - train loss = 0.700, val loss = 0.708
# 250 - train loss = 0.295, val loss = 0.312
# 255 - train loss = 0.290, val loss = 0.277
# 260 - train loss = 0.590, val loss = 0.598
# 265 - train loss = 0.214, val loss = 0.216
# 270 - train loss = 0.466, val loss = 0.473
# 275 - train loss = 0.529, val loss = 0.516
# 280 - train loss = 0.492, val loss = 0.488
# 285 - train loss = 0.699, val loss = 0.714
# 290 - train loss = 0.787, val loss = 0.788
# 295 - train loss = 0.674, val loss = 0.684
# 300 - train loss = 0.254, val loss = 0.248
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7           5        0.257915
# 1    0  random_hill_climb           7          10        0.244205
# 2    0  random_hill_climb           7          15        0.253371
# 3    0  random_hill_climb           7          20        0.719967
# 4    0  random_hill_climb           7          25        0.222769
# ..  ..                ...         ...         ...             ...
# 115  0  random_hill_climb         123         280        0.491516
# 116  0  random_hill_climb         123         285        0.698758
# 117  0  random_hill_climb         123         290        0.786850
# 118  0  random_hill_climb         123         295        0.673913
# 119  0  random_hill_climb         123         300        0.254128
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 115       0.488337     3.416941       0.487834  0.220702
# 116       0.714329     3.606679       0.702821  0.114010
# 117       0.787640     3.760521       0.786966  0.011990
# 118       0.684035     3.537883       0.671824  0.121286
# 119       0.248107     3.636626       0.254871  0.331057
#
# [120 rows x 9 columns]
# 5 - train loss = 0.515, val loss = 0.529
# 10 - train loss = 0.293, val loss = 0.285
# 15 - train loss = 0.784, val loss = 0.786
# 20 - train loss = 0.739, val loss = 0.739
# 25 - train loss = 0.212, val loss = 0.211
# 30 - train loss = 0.777, val loss = 0.776
# 35 - train loss = 0.388, val loss = 0.389
# 40 - train loss = 0.697, val loss = 0.694
# 45 - train loss = 0.345, val loss = 0.341
# 50 - train loss = 0.303, val loss = 0.306
# 55 - train loss = 0.788, val loss = 0.789
# 60 - train loss = 0.515, val loss = 0.511
# 65 - train loss = 0.467, val loss = 0.457
# 70 - train loss = 0.259, val loss = 0.257
# 75 - train loss = 0.789, val loss = 0.790
# 80 - train loss = 0.508, val loss = 0.512
# 85 - train loss = 0.788, val loss = 0.789
# 90 - train loss = 0.212, val loss = 0.211
# 95 - train loss = 0.771, val loss = 0.767
# 100 - train loss = 0.724, val loss = 0.734
# 105 - train loss = 0.664, val loss = 0.664
# 110 - train loss = 0.456, val loss = 0.460
# 115 - train loss = 0.224, val loss = 0.226
# 120 - train loss = 0.212, val loss = 0.211
# 125 - train loss = 0.410, val loss = 0.394
# 130 - train loss = 0.395, val loss = 0.392
# 135 - train loss = 0.730, val loss = 0.732
# 140 - train loss = 0.728, val loss = 0.723
# 145 - train loss = 0.780, val loss = 0.781
# 150 - train loss = 0.785, val loss = 0.787
# 155 - train loss = 0.480, val loss = 0.493
# 160 - train loss = 0.754, val loss = 0.754
# 165 - train loss = 0.788, val loss = 0.789
# 170 - train loss = 0.490, val loss = 0.493
# 175 - train loss = 0.212, val loss = 0.211
# 180 - train loss = 0.788, val loss = 0.789
# 185 - train loss = 0.783, val loss = 0.780
# 190 - train loss = 0.212, val loss = 0.211
# 195 - train loss = 0.429, val loss = 0.427
# 200 - train loss = 0.693, val loss = 0.701
# 205 - train loss = 0.785, val loss = 0.786
# 210 - train loss = 0.212, val loss = 0.211
# 215 - train loss = 0.256, val loss = 0.250
# 220 - train loss = 0.228, val loss = 0.226
# 225 - train loss = 0.711, val loss = 0.706
# 230 - train loss = 0.311, val loss = 0.311
# 235 - train loss = 0.345, val loss = 0.340
# 240 - train loss = 0.212, val loss = 0.212
# 245 - train loss = 0.353, val loss = 0.347
# 250 - train loss = 0.218, val loss = 0.217
# 255 - train loss = 0.788, val loss = 0.788
# 260 - train loss = 0.740, val loss = 0.736
# 265 - train loss = 0.212, val loss = 0.211
# 270 - train loss = 0.239, val loss = 0.240
# 275 - train loss = 0.389, val loss = 0.368
# 280 - train loss = 0.741, val loss = 0.739
# 285 - train loss = 0.394, val loss = 0.373
# 290 - train loss = 0.281, val loss = 0.276
# 295 - train loss = 0.714, val loss = 0.724
# 300 - train loss = 0.770, val loss = 0.773
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7           5        0.257915
# 1    0  random_hill_climb           7          10        0.244205
# 2    0  random_hill_climb           7          15        0.253371
# 3    0  random_hill_climb           7          20        0.719967
# 4    0  random_hill_climb           7          25        0.222769
# ..  ..                ...         ...         ...             ...
# 175  0  random_hill_climb       10000         280        0.740645
# 176  0  random_hill_climb       10000         285        0.394258
# 177  0  random_hill_climb       10000         290        0.280867
# 178  0  random_hill_climb       10000         295        0.713755
# 179  0  random_hill_climb       10000         300        0.769959
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 175       0.739170     3.432270       0.740793  0.036344
# 176       0.372917     3.686112       0.396916  0.328496
# 177       0.275977     3.635458       0.281330  0.355068
# 178       0.724023     3.740402       0.712597  0.118599
# 179       0.773099     3.570123       0.769057  0.169805
#
# [180 rows x 9 columns]
# Algorithm = simulated_annealing
# 5 - train loss = 0.691, val loss = 0.668
# 10 - train loss = 0.779, val loss = 0.782
# 15 - train loss = 0.698, val loss = 0.694
# 20 - train loss = 0.678, val loss = 0.662
# 25 - train loss = 0.779, val loss = 0.779
# 30 - train loss = 0.730, val loss = 0.744
# 35 - train loss = 0.220, val loss = 0.221
# 40 - train loss = 0.692, val loss = 0.687
# 45 - train loss = 0.688, val loss = 0.692
# 50 - train loss = 0.566, val loss = 0.570
# 55 - train loss = 0.418, val loss = 0.404
# 235 - train loss = 0.657, val loss = 0.651
# 240 - train loss = 0.758, val loss = 0.763
# 245 - train loss = 0.772, val loss = 0.765
# 250 - train loss = 0.768, val loss = 0.766
# 255 - train loss = 0.234, val loss = 0.226
# 260 - train loss = 0.255, val loss = 0.245
# 265 - train loss = 0.212, val loss = 0.213
# 270 - train loss = 0.752, val loss = 0.752
# 275 - train loss = 0.774, val loss = 0.770
# 280 - train loss = 0.229, val loss = 0.231
# 285 - train loss = 0.641, val loss = 0.644
# 290 - train loss = 0.463, val loss = 0.467
# 295 - train loss = 0.711, val loss = 0.719
# 300 - train loss = 0.785, val loss = 0.787
#      i            algorithm random_seed Itterations  train_accuracy  \
# 0    0    random_hill_climb           7           5        0.257915
# 1    0    random_hill_climb           7          10        0.244205
# 2    0    random_hill_climb           7          15        0.253371
# 3    0    random_hill_climb           7          20        0.719967
# 4    0    random_hill_climb           7          25        0.222769
# ..  ..                  ...         ...         ...             ...
# 355  1  simulated_annealing       10000         280        0.229283
# 356  1  simulated_annealing       10000         285        0.641418
# 357  1  simulated_annealing       10000         290        0.463036
# 358  1  simulated_annealing       10000         295        0.711029
# 359  1  simulated_annealing       10000         300        0.784578
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 355       0.231142     4.667307       0.231549  0.342955
# 356       0.644350     4.764074       0.640234  0.242601
# 357       0.467131     4.698341       0.460728  0.353704
# 358       0.719479     4.888705       0.708840  0.090974
# 359       0.787337     4.885333       0.787450  0.121054
#
# [360 rows x 9 columns]
# Algorithm = genetic_alg
# 5 - train loss = 0.800, val loss = 0.800
# 10 - train loss = 0.798, val loss = 0.797
# 15 - train loss = 0.795, val loss = 0.799
# 20 - train loss = 0.798, val loss = 0.799
# 25 - train loss = 0.798, val loss = 0.803
# 30 - train loss = 0.800, val loss = 0.804
# 35 - train loss = 0.800, val loss = 0.802
# 40 - train loss = 0.807, val loss = 0.810
# 45 - train loss = 0.805, val loss = 0.808
# 50 - train loss = 0.803, val loss = 0.801
# 55 - train loss = 0.806, val loss = 0.809
# 60 - train loss = 0.802, val loss = 0.804
# 65 - train loss = 0.806, val loss = 0.808
# 70 - train loss = 0.812, val loss = 0.814
# 75 - train loss = 0.804, val loss = 0.811
# 80 - train loss = 0.811, val loss = 0.808
# 85 - train loss = 0.804, val loss = 0.800
# 90 - train loss = 0.804, val loss = 0.806
# 95 - train loss = 0.803, val loss = 0.803
# 100 - train loss = 0.803, val loss = 0.802
# 105 - train loss = 0.810, val loss = 0.816
# 110 - train loss = 0.808, val loss = 0.813
# 115 - train loss = 0.804, val loss = 0.806
# 120 - train loss = 0.807, val loss = 0.806
# 125 - train loss = 0.807, val loss = 0.809
# 130 - train loss = 0.810, val loss = 0.811
# 135 - train loss = 0.804, val loss = 0.805
# 140 - train loss = 0.805, val loss = 0.808
# 145 - train loss = 0.813, val loss = 0.815
# 250 - train loss = 0.788, val loss = 0.789
# 255 - train loss = 0.786, val loss = 0.787
# 260 - train loss = 0.788, val loss = 0.789
# 265 - train loss = 0.788, val loss = 0.789
# 270 - train loss = 0.788, val loss = 0.789
# 275 - train loss = 0.788, val loss = 0.789
# 280 - train loss = 0.790, val loss = 0.789
# 285 - train loss = 0.791, val loss = 0.791
# 290 - train loss = 0.788, val loss = 0.789
# 295 - train loss = 0.788, val loss = 0.789
# 300 - train loss = 0.788, val loss = 0.789
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7           5        0.257915
# 1    0  random_hill_climb           7          10        0.244205
# 2    0  random_hill_climb           7          15        0.253371
# 3    0  random_hill_climb           7          20        0.719967
# 4    0  random_hill_climb           7          25        0.222769
# ..  ..                ...         ...         ...             ...
# 595  3   gradient_descent           7         280        0.789653
# 596  3   gradient_descent           7         285        0.791017
# 597  3   gradient_descent           7         290        0.788365
# 598  3   gradient_descent           7         295        0.788365
# 599  3   gradient_descent           7         300        0.788365
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 595       0.788549     8.228112       0.789834  0.029353
# 596       0.790669     8.343009       0.791099  0.070350
# 597       0.788549     8.442516       0.788406  0.000000
# 598       0.788549     8.565151       0.788406  0.000000
# 599       0.788549     8.744084       0.788406  0.000000
#
# [600 rows x 9 columns]
# 5 - train loss = 0.784, val loss = 0.779
# 10 - train loss = 0.788, val loss = 0.789
# 15 - train loss = 0.788, val loss = 0.789
# 20 - train loss = 0.788, val loss = 0.789
# 25 - train loss = 0.788, val loss = 0.789
# 30 - train loss = 0.788, val loss = 0.789
# 35 - train loss = 0.788, val loss = 0.789
# 40 - train loss = 0.788, val loss = 0.789
# 45 - train loss = 0.789, val loss = 0.788
# 50 - train loss = 0.786, val loss = 0.786
# 55 - train loss = 0.789, val loss = 0.789
# 60 - train loss = 0.788, val loss = 0.789
# 65 - train loss = 0.789, val loss = 0.789
# 70 - train loss = 0.788, val loss = 0.789
# 75 - train loss = 0.776, val loss = 0.773
# 80 - train loss = 0.788, val loss = 0.789
# 85 - train loss = 0.788, val loss = 0.789
# 90 - train loss = 0.788, val loss = 0.788
# 95 - train loss = 0.788, val loss = 0.789
# 100 - train loss = 0.788, val loss = 0.789
# 105 - train loss = 0.788, val loss = 0.788
# 110 - train loss = 0.792, val loss = 0.792
# 115 - train loss = 0.788, val loss = 0.789
# 120 - train loss = 0.788, val loss = 0.789
# 125 - train loss = 0.788, val loss = 0.789
# 130 - train loss = 0.776, val loss = 0.781
# 135 - train loss = 0.788, val loss = 0.788
# 140 - train loss = 0.787, val loss = 0.787
# 145 - train loss = 0.788, val loss = 0.788
# 150 - train loss = 0.788, val loss = 0.789
# 155 - train loss = 0.788, val loss = 0.789
# 160 - train loss = 0.789, val loss = 0.789
# 165 - train loss = 0.787, val loss = 0.788
# 170 - train loss = 0.788, val loss = 0.789
# 175 - train loss = 0.789, val loss = 0.789
# 180 - train loss = 0.788, val loss = 0.789
# 185 - train loss = 0.784, val loss = 0.786
# 190 - train loss = 0.787, val loss = 0.787
# 195 - train loss = 0.788, val loss = 0.789
# 200 - train loss = 0.788, val loss = 0.789
# 205 - train loss = 0.799, val loss = 0.797
# 210 - train loss = 0.788, val loss = 0.789
# 215 - train loss = 0.788, val loss = 0.789
# 220 - train loss = 0.795, val loss = 0.796
# 225 - train loss = 0.788, val loss = 0.789
# 230 - train loss = 0.793, val loss = 0.796
# 235 - train loss = 0.788, val loss = 0.789
# 240 - train loss = 0.788, val loss = 0.789
# 245 - train loss = 0.788, val loss = 0.789
# 250 - train loss = 0.788, val loss = 0.789
# 255 - train loss = 0.788, val loss = 0.789
# 260 - train loss = 0.788, val loss = 0.789
# 265 - train loss = 0.790, val loss = 0.791
# 270 - train loss = 0.788, val loss = 0.788
# 275 - train loss = 0.788, val loss = 0.789
# 280 - train loss = 0.788, val loss = 0.789
# 285 - train loss = 0.788, val loss = 0.789
# 290 - train loss = 0.788, val loss = 0.789
# 295 - train loss = 0.788, val loss = 0.789
# 300 - train loss = 0.788, val loss = 0.789
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7           5        0.257915
# 1    0  random_hill_climb           7          10        0.244205
# 2    0  random_hill_climb           7          15        0.253371
# 3    0  random_hill_climb           7          20        0.719967
# 4    0  random_hill_climb           7          25        0.222769
# ..  ..                ...         ...         ...             ...
# 655  3   gradient_descent         123         280        0.788365
# 656  3   gradient_descent         123         285        0.788365
# 657  3   gradient_descent         123         290        0.788365
# 658  3   gradient_descent         123         295        0.788365
# 659  3   gradient_descent         123         300        0.788365
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 655       0.788549     8.235606       0.788406  0.000000
# 656       0.788549     8.453734       0.788433  0.000255
# 657       0.788549     8.520329       0.788420  0.000255
# 658       0.788549     8.677390       0.788406  0.000000
# 659       0.788549     8.960470       0.788406  0.000000
#
# [660 rows x 9 columns]
# 5 - train loss = 0.670, val loss = 0.669
# 10 - train loss = 0.787, val loss = 0.788
# 15 - train loss = 0.788, val loss = 0.788
# 20 - train loss = 0.788, val loss = 0.789
# 25 - train loss = 0.794, val loss = 0.798
# 30 - train loss = 0.788, val loss = 0.789
# 35 - train loss = 0.788, val loss = 0.789
# 40 - train loss = 0.788, val loss = 0.788
# 45 - train loss = 0.793, val loss = 0.797
# 50 - train loss = 0.788, val loss = 0.788
# 55 - train loss = 0.787, val loss = 0.789
# 60 - train loss = 0.788, val loss = 0.788
# 65 - train loss = 0.789, val loss = 0.788
# 70 - train loss = 0.788, val loss = 0.789
# 75 - train loss = 0.788, val loss = 0.789
# 80 - train loss = 0.788, val loss = 0.789
# 85 - train loss = 0.788, val loss = 0.788
# 90 - train loss = 0.781, val loss = 0.785
# 95 - train loss = 0.788, val loss = 0.789
# 100 - train loss = 0.788, val loss = 0.788
# 105 - train loss = 0.788, val loss = 0.788
# 110 - train loss = 0.788, val loss = 0.788
# 115 - train loss = 0.785, val loss = 0.785
# 120 - train loss = 0.788, val loss = 0.789
# 125 - train loss = 0.788, val loss = 0.789
# 130 - train loss = 0.788, val loss = 0.789
# 135 - train loss = 0.788, val loss = 0.789
# 140 - train loss = 0.788, val loss = 0.789
# 145 - train loss = 0.786, val loss = 0.789
# 150 - train loss = 0.788, val loss = 0.789
# 155 - train loss = 0.788, val loss = 0.789
# 160 - train loss = 0.788, val loss = 0.788
# 165 - train loss = 0.788, val loss = 0.788
# 170 - train loss = 0.789, val loss = 0.789
# 175 - train loss = 0.788, val loss = 0.789
# 180 - train loss = 0.783, val loss = 0.784
# 185 - train loss = 0.788, val loss = 0.789
# 190 - train loss = 0.785, val loss = 0.786
# 195 - train loss = 0.788, val loss = 0.788
# 200 - train loss = 0.788, val loss = 0.789
# 205 - train loss = 0.788, val loss = 0.786
# 210 - train loss = 0.788, val loss = 0.789
# 215 - train loss = 0.789, val loss = 0.788
# 220 - train loss = 0.788, val loss = 0.789
# 225 - train loss = 0.787, val loss = 0.786
# 230 - train loss = 0.794, val loss = 0.792
# 235 - train loss = 0.788, val loss = 0.789
# 240 - train loss = 0.789, val loss = 0.789
# 245 - train loss = 0.788, val loss = 0.789
# 250 - train loss = 0.788, val loss = 0.789
# 255 - train loss = 0.788, val loss = 0.789
# 260 - train loss = 0.788, val loss = 0.789
# 265 - train loss = 0.788, val loss = 0.788
# 270 - train loss = 0.788, val loss = 0.789
# 275 - train loss = 0.788, val loss = 0.789
# 280 - train loss = 0.789, val loss = 0.789
# 285 - train loss = 0.788, val loss = 0.789
# 290 - train loss = 0.788, val loss = 0.789
# 295 - train loss = 0.747, val loss = 0.758
# 300 - train loss = 0.789, val loss = 0.790
#      i          algorithm random_seed Itterations  train_accuracy  \
# 0    0  random_hill_climb           7           5        0.257915
# 1    0  random_hill_climb           7          10        0.244205
# 2    0  random_hill_climb           7          15        0.253371
# 3    0  random_hill_climb           7          20        0.719967
# 4    0  random_hill_climb           7          25        0.222769
# ..  ..                ...         ...         ...             ...
# 715  3   gradient_descent       10000         280        0.788820
# 716  3   gradient_descent       10000         285        0.788365
# 717  3   gradient_descent       10000         290        0.788365
# 718  3   gradient_descent       10000         295        0.746857
# 719  3   gradient_descent       10000         300        0.789199
#
#      val_acccuracy  train_times  test_accuracy   test_F1
# 0         0.252651     0.046884       0.262156  0.315324
# 1         0.244471     0.157628       0.244328  0.350027
# 2         0.250530     0.187514       0.252191  0.355566
# 3         0.712814     0.263301       0.716811  0.236153
# 4         0.226901     0.332401       0.226257  0.346934
# ..             ...          ...            ...       ...
# 715       0.788852     8.246019       0.788568  0.005699
# 716       0.788549     8.342892       0.788406  0.000000
# 717       0.788549     8.564368       0.788406  0.000000
# 718       0.757649     8.727134       0.744052  0.241319
# 719       0.790064     8.952085       0.788743  0.028003
#
# [720 rows x 9 columns]

# %%
import openpyxl

# %%
df = pd.read_excel(r'C:\Users\sagni\Documents\Personal Files\CS7641\Assignment2\NN_Images\F1_score.xlsx', engine='openpyxl')
header = 24
other_title = 18

#Plot RHC Train vs Test
plt.clf()
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
plt.plot(df[['Itterations']], df[['random_hill_climb']], color='green', label='RHC', alpha=0.8)
plt.plot(df[['Itterations']], df[['genetic_alg']], color='orange', label='GA', alpha=0.8)
plt.plot(df[['Itterations']], df[['simulated_annealing']], color='blue', label='SA', alpha=0.8)
plt.plot(df[['Itterations']], df[['gradient_descent']], color='purple', label='Backprop', alpha=0.8)
plt.xlabel('Iterations', fontsize=other_title)
plt.ylabel('F1 Score (%)', fontsize=other_title)
title = "F1 Score Vs. Iterations"
plt.title(title, fontsize=header)
plt.legend(loc='upper right', frameon=True, edgecolor='black', facecolor='white', fontsize=other_title)
plt.tick_params(direction='in', bottom=True, top=True, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.grid(True, linestyle="dotted", alpha=0.45, color='black')
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.ylim(0, 1)
h1 = 'C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/F1ScoreVsIterations.png'
plt.savefig(h1, dpi=600)
plt.show()

# %%
df = pd.read_excel(r'C:\Users\sagni\Documents\Personal Files\CS7641\Assignment2\NN_Images\Accuracy.xlsx', engine='openpyxl')
header = 24
other_title = 18

#Plot RHC Train vs Test
plt.clf()
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
plt.plot(df[['iterations']], df[['RHC_Val']], color='green', label='RHC', alpha=0.8)
plt.plot(df[['iterations']], df[['GA_Val']], color='orange', label='GA', alpha=0.8)
plt.plot(df[['iterations']], df[['SA_Val']], color='blue', label='SA', alpha=0.8)
plt.plot(df[['iterations']], df[['GD_Val']], color='purple', label='Backprop', alpha=0.8)
plt.xlabel('Iterations', fontsize=other_title)
plt.ylabel('Validation Accuracy (%)', fontsize=other_title)
title = "Validation Accuracy Vs. Iterations"
plt.title(title, fontsize=header)
plt.legend(loc='lower right', frameon=True, edgecolor='black', facecolor='white', fontsize=other_title)
plt.tick_params(direction='in', bottom=True, top=True, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.grid(True, linestyle="dotted", alpha=0.45, color='black')
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.ylim(0, 1)
h1 = 'C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/ValAccuracyVsIterations.png'
plt.savefig(h1, dpi=600)
plt.show()

# %%
df = pd.read_excel(r'C:\Users\sagni\Documents\Personal Files\CS7641\Assignment2\NN_Images\Accuracy.xlsx', engine='openpyxl')
header = 24
other_title = 18

#Plot RHC Train vs Test
plt.clf()
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
plt.plot(df[['iterations']], df[['RHC_Time']], color='green', label='RHC', alpha=0.8)
plt.plot(df[['iterations']], df[['GA_Time']], color='orange', label='GA', alpha=0.8)
plt.plot(df[['iterations']], df[['SA_Time']], color='blue', label='SA', alpha=0.8)
plt.plot(df[['iterations']], df[['GD_Time']], color='purple', label='Backprop', alpha=0.8)
plt.xlabel('Iterations', fontsize=other_title)
plt.ylabel('Training Time', fontsize=other_title)
title = "Training Time Vs. Iterations"
plt.title(title, fontsize=header)
plt.legend(loc='upper left', frameon=True, edgecolor='black', facecolor='white', fontsize=other_title)
plt.tick_params(direction='in', bottom=True, top=True, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.grid(True, linestyle="dotted", alpha=0.45, color='black')
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
h1 = 'C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/TrainingTimeVsIterations.png'
plt.savefig(h1, dpi=600)
plt.show()

# %%
df = pd.read_excel(r'C:\Users\sagni\Documents\Personal Files\CS7641\Assignment2\NN_Images\Accuracy.xlsx', engine='openpyxl')
header = 24
other_title = 18

#Plot RHC Train vs Test
plt.clf()
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
plt.plot(df[['iterations']], df[['RHC_Time']], color='green', label='RHC', alpha=0.8)
plt.plot(df[['iterations']], df[['GA_Time']], color='orange', label='GA', alpha=0.8)
plt.plot(df[['iterations']], df[['SA_Time']], color='blue', label='SA', alpha=0.8)
plt.plot(df[['iterations']], df[['GD_Time']], color='purple', label='Backprop', alpha=0.8)
plt.xlabel('Iterations', fontsize=other_title)
plt.ylabel('Training Time', fontsize=other_title)
title = "Training Time Vs. Iterations"
plt.title(title, fontsize=header)
plt.legend(loc='upper left', frameon=True, edgecolor='black', facecolor='white', fontsize=other_title)
plt.tick_params(direction='in', bottom=True, top=True, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.grid(True, linestyle="dotted", alpha=0.45, color='black')
plt.yscale('log')
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
h1 = 'C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/TrainingTimeVsIterations_log.png'
plt.savefig(h1, dpi=600)
plt.show()

# %%
max_iter = 1000
print('start')
model_rhc = NeuralNetwork(hidden_nodes=[32,], activation='relu',
                                   algorithm='random_hill_climb', max_iters=int(max_iter),
                                   bias=True, is_classifier=True, learning_rate=0.01, restarts=50,
                                   max_attempts=100, early_stopping=True, curve=True)
model_rhc.fit(trainX, trainY)
probs_rhc = model_rhc.predict(testX)
cm1 = confusion_matrix(testY, probs_rhc)
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - RHC', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_RHC.png', dpi=600)
plt.show()
precision1 = precision_score(testY, probs_rhc)
recall1 = recall_score(testY, probs_rhc)
f1_score1 = f1_score(testY, probs_rhc)
accuracy1 = accuracy_score(testY, probs_rhc)
print('Model 1: RHC')
print('Precision:', precision1)
print('Recall:', recall1)
print('F1 Score:', f1_score1)
print('Accuracy:', accuracy1)
print('RHC Done')
# Out:
# start
# Model 1: RHC
# Precision: 0.23940677966101695
# Recall: 0.05997876857749469
# F1 Score: 0.09592529711375211
# Accuracy: 0.73375
# RHC Done

# %%
max_iter = 1000
print('start')
model_rhc = NeuralNetwork(hidden_nodes=[16,4], activation='relu',
                                   algorithm='simulated_annealing', max_iters=int(max_iter),
                                   bias=True, is_classifier=True, learning_rate=0.001, schedule=mlrose.GeomDecay(decay=0.8),
                                   max_attempts=100, early_stopping=True, random_state=1000, curve=True)
model_rhc.fit(trainX, trainY)
probs_rhc = model_rhc.predict(testX)
cm1 = confusion_matrix(testY, probs_rhc)
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - SA', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_SA.png', dpi=600)
precision1 = precision_score(testY, probs_rhc)
recall1 = recall_score(testY, probs_rhc)
f1_score1 = f1_score(testY, probs_rhc)
accuracy1 = accuracy_score(testY, probs_rhc)
print('Model 2: SA')
print('Precision:', precision1)
print('Recall:', recall1)
print('F1 Score:', f1_score1)
print('Accuracy:', accuracy1)
print('SA Done')
# Out:
# start
# Model 2: SA
# Precision: 0.7643000501756146
# Recall: 0.9962393721386528
# F1 Score: 0.8649914821124361
# Accuracy: 0.76225
# SA Done

# %%
max_iter = 1000
print('start')
model_rhc = NeuralNetwork(hidden_nodes=[32,], activation='relu',
                                   algorithm='genetic_alg', max_iters=int(max_iter),
                                   bias=True, is_classifier=True, learning_rate=0.001,
                                   max_attempts=1000, early_stopping=True, random_state=1000, curve=True,
                                pop_size=kwargs50, mutation_prob=0.8)
model_rhc.fit(trainX, trainY)
probs_rhc = model_rhc.predict(testX)
cm1 = confusion_matrix(testY, probs_rhc)
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - GA', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_GA.png', dpi=600)
precision1 = precision_score(testY, probs_rhc)
recall1 = recall_score(testY, probs_rhc)
f1_score1 = f1_score(testY, probs_rhc)
accuracy1 = accuracy_score(testY, probs_rhc)
print('Model 3: GA')
print('Precision:', precision1)
print('Recall:', recall1)
print('F1 Score:', f1_score1)
print('Accuracy:', accuracy1)
print('SA Done')
# Out:
# start
# Model 3: GA
# Precision: 0.7796338366965121
# Recall: 0.9538914323086986
# F1 Score: 0.8580042650194867
# Accuracy: 0.758625
# SA Done

# %%
max_iter = 1000
print('start')
model_rhc = NeuralNetwork(hidden_nodes=[16,], activation='relu',
                                   algorithm='gradient_descent', max_iters=int(max_iter),
                                   bias=True, is_classifier=True, learning_rate=0.01,
                                   max_attempts=100, early_stopping=True, random_state=12345, curve=True)
model_rhc.fit(trainX, trainY)
probs_rhc = model_rhc.predict(testX)
cm1 = confusion_matrix(testY, probs_rhc)
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - Back Prop', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_GD.png', dpi=600)
precision1 = precision_score(testY, probs_rhc)
recall1 = recall_score(testY, probs_rhc)
f1_score1 = f1_score(testY, probs_rhc)
accuracy1 = accuracy_score(testY, probs_rhc)
print('Model 4: BP')
print('Precision:', precision1)
print('Recall:', recall1)
print('F1 Score:', f1_score1)
print('Accuracy:', accuracy1)
print('BP Done')
# Out:
# start
# Model 4: BP
# Precision: 0.4
# Recall: 0.010615711252653927
# F1 Score: 0.020682523267838676
# Accuracy: 0.76325
# BP Done

# %%
#RHC
cm1 = np.array([[57, 20],
                [9, 14]])
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - RHC', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_RHC.png', dpi=600)
plt.show()

#SA
cm1 = np.array([[48, 29],
                [16, 7]])
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - SA', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_SA.png', dpi=600)
plt.show()

#GA
cm1 = np.array([[63, 14],
                [7, 16]])
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - GA', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_GA.png', dpi=600)
plt.show()

#GD
cm1 = np.array([[65, 12],
                [9, 14]])
plt.clf()
header = 24
other_title = 18
plt.figure(figsize=(12, 8))
plt.gcf().set_facecolor('white')
fig, ax = plt.subplots(figsize=(12, 8))
fig.set_facecolor('white')
ax.set_facecolor('white')
sns.heatmap(cm1/cm1.sum(), annot=True, cmap='Blues', fmt='.0%', cbar=False, annot_kws={"fontsize": 18}, linewidths=1, linecolor='black')
plt.title('Confusion Matrix - Back Prop', fontsize=header)
plt.xticks(fontsize=other_title)
plt.yticks(fontsize=other_title)
plt.tick_params(direction='out', bottom=True, top=False, left=True, right=True, length=4)
plt.gca().spines['top'].set_color('black')
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().spines['right'].set_color('black')
spine_alpha = 0.5
plt.gca().spines['top'].set_alpha(spine_alpha)
plt.gca().spines['bottom'].set_alpha(spine_alpha)
plt.gca().spines['left'].set_alpha(spine_alpha)
plt.gca().spines['right'].set_alpha(spine_alpha)
plt.xlabel('Predicted Label', fontsize=other_title)
plt.ylabel('True Label', fontsize=other_title)
plt.savefig('C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/CM_GD.png', dpi=600)
plt.show()
