# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import utils
import pandas as pd
import gc
import mlrose_hiive as mlrose

from mlrose_hiive.algorithms.decay import ExpDecay
from mlrose_hiive.neural import NeuralNetwork

from sklearn.metrics import log_loss, classification_report, accuracy_score, f1_score
from sklearn.model_selection import train_test_split

class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    END = '\033[0m'

# %%
def NN_RHC_Restarts(trainX, trainY, testX, testY):
    
    gc.collect()
    max_iters = [100 * (i+1) for i in range(5)]
    seeds = [10 * (10**i) for i in range(4)]
    restarts = [0, 1, 50]
    color = ['blue', 'green', 'purple']
    algorithm = 'random_hill_climb'
    header = 24
    other_title = 18
    Output = pd.DataFrame(columns=['algorithm', 'random_seed', 'Itterations', 'restarts', 'train_accuracy', 'test_accuracy'])
    
    for max_iter in max_iters:
        for restart in restarts:
            for seed in seeds:
                gc.collect()
                # Define neural network classifier
                nn = NeuralNetwork(hidden_nodes=[8,], activation='relu',
                                       algorithm=algorithm, max_iters=int(max_iter),
                                       bias=True, is_classifier=True, learning_rate=0.1, restarts = restart,
                                       early_stopping=False, random_state=seed, curve=True)

                nn.fit(trainX, trainY)
                      
                train_accuracy = accuracy_score(trainY, pd.DataFrame(nn.predict(trainX), index=trainY.index))
                test_accuracy = accuracy_score(testY, pd.DataFrame(nn.predict(testX), index=testY.index))

                Output = Output.append({'algorithm' : algorithm,
                                        'random_seed' : seed,
                                        'Itterations' : max_iter,
                                        'restarts' : restart,
                                        'train_accuracy' : train_accuracy,
                                        'test_accuracy' : test_accuracy}, ignore_index=True)
                display(Output)
    
    Output = Output.groupby(['restarts', 'Itterations']).agg({'train_accuracy': ['mean', 'std'], 'test_accuracy': ['mean', 'std']}).reset_index()
    # Rename the columns
    Output.columns = ['restarts', 'Itterations', 'mean_train_accuracy', 'std_train_accuracy', 'mean_test_accuracy', 'std_test_accuracy']
    
    
    #################################
    ####plot train accuracy
    #################################
    # Plot fitness vs iteration with separate lines for each temperature
    plt.clf()
    plt.figure(figsize=(12, 8))
    plt.gcf().set_facecolor('white')
    fig, ax = plt.subplots(figsize=(12, 8))
    fig.set_facecolor('white')
    ax.set_facecolor('white')
    for restart in restarts:
        temp_data = Output[Output['restarts'] == restart]
        plt.plot(temp_data['Itterations'], temp_data['mean_train_accuracy'], label=f'Restarts (Train) {restart}', color=color[restarts.index(restart)], alpha=0.8)
        plt.plot(temp_data['Itterations'], temp_data['mean_test_accuracy'], label=f'Restarts (Test) {restart}', color=color[restarts.index(restart)], alpha=0.7, linestyle='--')
        upper_bound = temp_data['mean_train_accuracy'] + temp_data['std_train_accuracy']
        lower_bound = temp_data['mean_train_accuracy'] - temp_data['std_train_accuracy']
        plt.fill_between(temp_data['Itterations'], upper_bound, lower_bound, color=color[restarts.index(restart)], alpha=0.2)

    plt.xlabel('Iterations', fontsize=other_title)
    plt.ylabel('Accuracy', fontsize=other_title)
    full_title = 'Varying Restats\nFor Random Hill Climb'
    plt.title(full_title, fontsize=header)
    plt.legend(loc='lower right', frameon=True, edgecolor='black', facecolor='white', fontsize=other_title)
    plt.tick_params(direction='in', bottom=True, top=True, left=True, right=True, length=4)
    plt.gca().spines['top'].set_color('black')
    plt.gca().spines['bottom'].set_color('black')
    plt.gca().spines['left'].set_color('black')
    plt.gca().spines['right'].set_color('black')
    spine_alpha = 0.5
    plt.gca().spines['top'].set_alpha(spine_alpha)
    plt.gca().spines['bottom'].set_alpha(spine_alpha)
    plt.gca().spines['left'].set_alpha(spine_alpha)
    plt.gca().spines['right'].set_alpha(spine_alpha)
    plt.grid(True, linestyle="dotted", alpha=0.45, color='black')
    plt.xticks(fontsize=other_title)
    plt.yticks(fontsize=other_title)
    h1 = 'C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/NN_Images/NN_RHC_restarts_gridsearch.png'
    plt.savefig(h1, dpi=600)
    plt.show()

# %%
#stratified sampling in sklearn
def stratified_sampling(vegito, target, size = 0.4, seed = 903949505):
    gc.collect()
    goku, vegita = train_test_split(vegito, test_size=size, stratify=vegito[target], random_state=seed)
    print(color.BOLD + color.UNDERLINE + color.DARKCYAN + "Original distribution" + color.END)
    c = vegito[target].value_counts(normalize=False)
    p = vegito[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.WARNING + "Train distribution" + color.END)
    c = goku[target].value_counts(normalize=False)
    p = goku[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.RED + "Test distribution" + color.END)
    c = vegita[target].value_counts(normalize=False)
    p = vegita[target].value_counts(normalize=True)*100
    display(pd.concat([c,p], axis=1, keys=['counts', '%']))
    
    #split goku, vegita and cell by target variable to make depent and indepent data seperately
    goku_X = goku.drop(target, axis=1)
    vegita_X = vegita.drop(target, axis=1)
    goku_y = pd.DataFrame(goku[target])
    vegita_y = pd.DataFrame(vegita[target])
    
    #return goku_X, goku_y, vegita_X, vegita_y
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_x shape" + color.END)
    print("Number of columns are " + color.BOLD + str(goku_X.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(goku_X.shape[1]) + color.END)
    display(goku_X.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_y shape" + color.END)
    print("Number of columns are " + color.BOLD + str(goku_y.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(goku_y.shape[1]) + color.END)
    display(goku_y.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_x shape" + color.END)
    print("Number of columns are " + color.BOLD + str(vegita_X.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(vegita_X.shape[1]) + color.END)
    display(vegita_X.head())
    print("\n" + "\n" + color.BOLD + color.UNDERLINE + color.BLUE + "Train_y shape" + color.END)
    print("Number of columns are " + color.BOLD + str(vegita_y.shape[0]) + color.END + " and number of rows are " + color.BOLD + str(vegita_y.shape[1]) + color.END)
    display(vegita_y.head())
    return goku_X, goku_y, vegita_X, vegita_y

# %%
data = pd.read_csv("C:/Users/sagni/Documents/Personal Files/CS7641/CS7641/Data/Self_generated/Generated_data.csv")
trainX, trainY, testX, testY = stratified_sampling(data, 'target', 0.6, 903949505)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(trainX)
trainX = pd.DataFrame(scaler.transform(trainX), columns=trainX.columns, index=trainX.index)
testX = pd.DataFrame(scaler.transform(testX), columns=testX.columns, index=testX.index)
display(trainX.head())
display(testX.head())
# Out:
# Original distribution
#    counts      %
# 1    7645  76.45
# 0    2355  23.55
# Train distribution
#    counts      %
# 1    3058  76.45
# 0     942  23.55
# Test distribution
#    counts      %
# 1    4587  76.45
# 0    1413  23.55
# Train_x shape
# Number of columns are 4000 and number of rows are 145
#        feature_1   feature_2    feature_3   feature_4   feature_5   feature_6  \
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
#
#    test_accuracy
# 0          0.236
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
# 5  random_hill_climb         100         100        1         0.67500
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
# 5       0.680833
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
# 5  random_hill_climb         100         100        1         0.67500
# 6  random_hill_climb        1000         100        1         0.23425
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
# 5       0.680833
# 6       0.237667
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
# 5  random_hill_climb         100         100        1         0.67500
# 6  random_hill_climb        1000         100        1         0.23425
# 7  random_hill_climb       10000         100        1         0.76450
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
# 5       0.680833
# 6       0.237667
# 7       0.764500
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
# 5  random_hill_climb         100         100        1         0.67500
# 6  random_hill_climb        1000         100        1         0.23425
# 7  random_hill_climb       10000         100        1         0.76450
# 8  random_hill_climb          10         100       50         0.76475
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
# 5       0.680833
# 6       0.237667
# 7       0.764500
# 8       0.764167
#            algorithm random_seed Itterations restarts  train_accuracy  \
# 0  random_hill_climb          10         100        0         0.23625
# 1  random_hill_climb         100         100        0         0.67500
# 2  random_hill_climb        1000         100        0         0.23425
# 3  random_hill_climb       10000         100        0         0.23550
# 4  random_hill_climb          10         100        1         0.76450
# 5  random_hill_climb         100         100        1         0.67500
# 6  random_hill_climb        1000         100        1         0.23425
# 7  random_hill_climb       10000         100        1         0.76450
# 8  random_hill_climb          10         100       50         0.76475
# 9  random_hill_climb         100         100       50         0.75600
#
#    test_accuracy
# 0       0.236000
# 1       0.680833
# 2       0.237667
# 3       0.235500
# 4       0.764500
# 5       0.680833
# 6       0.237667
# 7       0.764500
# 8       0.764167
# 9       0.755000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
# 28  random_hill_climb          10         300        1         0.26500
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
# 28       0.273833
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
# 28  random_hill_climb          10         300        1         0.26500
# 29  random_hill_climb         100         300        1         0.72075
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
# 28       0.273833
# 29       0.728333
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# ...
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
# 28  random_hill_climb          10         300        1         0.26500
# 29  random_hill_climb         100         300        1         0.72075
# 30  random_hill_climb        1000         300        1         0.73900
# 31  random_hill_climb       10000         300        1         0.74750
# 32  random_hill_climb          10         300       50         0.76450
# 33  random_hill_climb         100         300       50         0.76450
# 34  random_hill_climb        1000         300       50         0.75850
# 35  random_hill_climb       10000         300       50         0.76450
# 36  random_hill_climb          10         400        0         0.28325
# 37  random_hill_climb         100         400        0         0.73025
# 38  random_hill_climb        1000         400        0         0.26325
# 39  random_hill_climb       10000         400        0         0.23700
# 40  random_hill_climb          10         400        1         0.34875
# 41  random_hill_climb         100         400        1         0.76450
# 42  random_hill_climb        1000         400        1         0.73400
# 43  random_hill_climb       10000         400        1         0.76475
# 44  random_hill_climb          10         400       50         0.76500
# 45  random_hill_climb         100         400       50         0.75350
# 46  random_hill_climb        1000         400       50         0.76450
# 47  random_hill_climb       10000         400       50         0.76475
# 48  random_hill_climb          10         500        0         0.38275
# 49  random_hill_climb         100         500        0         0.74575
# 50  random_hill_climb        1000         500        0         0.28150
# 51  random_hill_climb       10000         500        0         0.24200
# 52  random_hill_climb          10         500        1         0.66750
# 53  random_hill_climb         100         500        1         0.75900
# 54  random_hill_climb        1000         500        1         0.28150
# 55  random_hill_climb       10000         500        1         0.76450
# 56  random_hill_climb          10         500       50         0.76600
# 57  random_hill_climb         100         500       50         0.76475
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
# 28       0.273833
# 29       0.728333
# 30       0.738000
# 31       0.742333
# 32       0.764000
# 33       0.764500
# 34       0.755167
# 35       0.764333
# 36       0.279000
# 37       0.733500
# 38       0.261333
# 39       0.235667
# 40       0.354500
# 41       0.764500
# 42       0.730333
# 43       0.764500
# 44       0.765167
# 45       0.754167
# 46       0.763500
# 47       0.764500
# 48       0.378000
# 49       0.748500
# 50       0.276667
# 51       0.237833
# 52       0.659667
# 53       0.754500
# 54       0.276667
# 55       0.764500
# 56       0.764333
# 57       0.762000
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
# 28  random_hill_climb          10         300        1         0.26500
# 29  random_hill_climb         100         300        1         0.72075
# 30  random_hill_climb        1000         300        1         0.73900
# 31  random_hill_climb       10000         300        1         0.74750
# 32  random_hill_climb          10         300       50         0.76450
# 33  random_hill_climb         100         300       50         0.76450
# 34  random_hill_climb        1000         300       50         0.75850
# 35  random_hill_climb       10000         300       50         0.76450
# 36  random_hill_climb          10         400        0         0.28325
# 37  random_hill_climb         100         400        0         0.73025
# 38  random_hill_climb        1000         400        0         0.26325
# 39  random_hill_climb       10000         400        0         0.23700
# 40  random_hill_climb          10         400        1         0.34875
# 41  random_hill_climb         100         400        1         0.76450
# 42  random_hill_climb        1000         400        1         0.73400
# 43  random_hill_climb       10000         400        1         0.76475
# 44  random_hill_climb          10         400       50         0.76500
# 45  random_hill_climb         100         400       50         0.75350
# 46  random_hill_climb        1000         400       50         0.76450
# 47  random_hill_climb       10000         400       50         0.76475
# 48  random_hill_climb          10         500        0         0.38275
# 49  random_hill_climb         100         500        0         0.74575
# 50  random_hill_climb        1000         500        0         0.28150
# 51  random_hill_climb       10000         500        0         0.24200
# 52  random_hill_climb          10         500        1         0.66750
# 53  random_hill_climb         100         500        1         0.75900
# 54  random_hill_climb        1000         500        1         0.28150
# 55  random_hill_climb       10000         500        1         0.76450
# 56  random_hill_climb          10         500       50         0.76600
# 57  random_hill_climb         100         500       50         0.76475
# 58  random_hill_climb        1000         500       50         0.75875
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
# 28       0.273833
# 29       0.728333
# 30       0.738000
# 31       0.742333
# 32       0.764000
# 33       0.764500
# 34       0.755167
# 35       0.764333
# 36       0.279000
# 37       0.733500
# 38       0.261333
# 39       0.235667
# 40       0.354500
# 41       0.764500
# 42       0.730333
# 43       0.764500
# 44       0.765167
# 45       0.754167
# 46       0.763500
# 47       0.764500
# 48       0.378000
# 49       0.748500
# 50       0.276667
# 51       0.237833
# 52       0.659667
# 53       0.754500
# 54       0.276667
# 55       0.764500
# 56       0.764333
# 57       0.762000
# 58       0.758500
#             algorithm random_seed Itterations restarts  train_accuracy  \
# 0   random_hill_climb          10         100        0         0.23625
# 1   random_hill_climb         100         100        0         0.67500
# 2   random_hill_climb        1000         100        0         0.23425
# 3   random_hill_climb       10000         100        0         0.23550
# 4   random_hill_climb          10         100        1         0.76450
# 5   random_hill_climb         100         100        1         0.67500
# 6   random_hill_climb        1000         100        1         0.23425
# 7   random_hill_climb       10000         100        1         0.76450
# 8   random_hill_climb          10         100       50         0.76475
# 9   random_hill_climb         100         100       50         0.75600
# 10  random_hill_climb        1000         100       50         0.74750
# 11  random_hill_climb       10000         100       50         0.76500
# 12  random_hill_climb          10         200        0         0.24025
# 13  random_hill_climb         100         200        0         0.71500
# 14  random_hill_climb        1000         200        0         0.23625
# 15  random_hill_climb       10000         200        0         0.23550
# 16  random_hill_climb          10         200        1         0.69000
# 17  random_hill_climb         100         200        1         0.71500
# 18  random_hill_climb        1000         200        1         0.23625
# 19  random_hill_climb       10000         200        1         0.75325
# 20  random_hill_climb          10         200       50         0.76300
# 21  random_hill_climb         100         200       50         0.76050
# 22  random_hill_climb        1000         200       50         0.74475
# 23  random_hill_climb       10000         200       50         0.76450
# 24  random_hill_climb          10         300        0         0.25000
# 25  random_hill_climb         100         300        0         0.72075
# 26  random_hill_climb        1000         300        0         0.24625
# 27  random_hill_climb       10000         300        0         0.23550
# 28  random_hill_climb          10         300        1         0.26500
# 29  random_hill_climb         100         300        1         0.72075
# 30  random_hill_climb        1000         300        1         0.73900
# 31  random_hill_climb       10000         300        1         0.74750
# 32  random_hill_climb          10         300       50         0.76450
# 33  random_hill_climb         100         300       50         0.76450
# 34  random_hill_climb        1000         300       50         0.75850
# 35  random_hill_climb       10000         300       50         0.76450
# 36  random_hill_climb          10         400        0         0.28325
# 37  random_hill_climb         100         400        0         0.73025
# 38  random_hill_climb        1000         400        0         0.26325
# 39  random_hill_climb       10000         400        0         0.23700
# 40  random_hill_climb          10         400        1         0.34875
# 41  random_hill_climb         100         400        1         0.76450
# 42  random_hill_climb        1000         400        1         0.73400
# 43  random_hill_climb       10000         400        1         0.76475
# 44  random_hill_climb          10         400       50         0.76500
# 45  random_hill_climb         100         400       50         0.75350
# 46  random_hill_climb        1000         400       50         0.76450
# 47  random_hill_climb       10000         400       50         0.76475
# 48  random_hill_climb          10         500        0         0.38275
# 49  random_hill_climb         100         500        0         0.74575
# 50  random_hill_climb        1000         500        0         0.28150
# 51  random_hill_climb       10000         500        0         0.24200
# 52  random_hill_climb          10         500        1         0.66750
# 53  random_hill_climb         100         500        1         0.75900
# 54  random_hill_climb        1000         500        1         0.28150
# 55  random_hill_climb       10000         500        1         0.76450
# 56  random_hill_climb          10         500       50         0.76600
# 57  random_hill_climb         100         500       50         0.76475
# 58  random_hill_climb        1000         500       50         0.75875
# 59  random_hill_climb       10000         500       50         0.75550
#
#     test_accuracy
# 0        0.236000
# 1        0.680833
# 2        0.237667
# 3        0.235500
# 4        0.764500
# 5        0.680833
# 6        0.237667
# 7        0.764500
# 8        0.764167
# 9        0.755000
# 10       0.752000
# 11       0.764333
# 12       0.239833
# 13       0.721333
# 14       0.240000
# 15       0.235500
# 16       0.692500
# 17       0.721333
# 18       0.240000
# 19       0.755333
# 20       0.763167
# 21       0.761167
# 22       0.748833
# 23       0.764500
# 24       0.245833
# 25       0.728333
# 26       0.249000
# 27       0.235667
# 28       0.273833
# 29       0.728333
# 30       0.738000
# 31       0.742333
# 32       0.764000
# 33       0.764500
# 34       0.755167
# 35       0.764333
# 36       0.279000
# 37       0.733500
# 38       0.261333
# 39       0.235667
# 40       0.354500
# 41       0.764500
# 42       0.730333
# 43       0.764500
# 44       0.765167
# 45       0.754167
# 46       0.763500
# 47       0.764500
# 48       0.378000
# 49       0.748500
# 50       0.276667
# 51       0.237833
# 52       0.659667
# 53       0.754500
# 54       0.276667
# 55       0.764500
# 56       0.764333
# 57       0.762000
# 58       0.758500
# 59       0.758667
