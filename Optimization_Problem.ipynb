# %%
# %run Base_with_funtions.ipynb

# %%
MayTheBestManWin(problem = mlrose.FourPeaks(t_pct=.5), max_iters = 3000, subtitle = "(Four Peaks)", subtitle2 = "FourPeaks")

# %%
MayTheBestManWin(problem = mlrose.FlipFlop(), max_iters = 1000, subtitle = "(Flip Flop)", subtitle2 = "FlipFlop")

# %%
MayTheBestManWin(problem = mlrose.OneMax(), max_iters = 1000, subtitle = "(One Max)", subtitle2 = "OneMax")

# %%
fitness = mlrose.FourPeaks(t_pct=.5)
RHC,RHC_curve,GA,GA_curve,SA,SA_curve,MIMIC,MIMIC_curve = fuction_runner(fitness, SA_schedule=mlrose.GeomDecay(init_temp=1000), GA_pop_size=200, GA_mutation_prob=0.5, MIMIC_pop_size = 200, MIMIC_keep_pct=0.2)
FittnessVsIterations_plotter(RHC_curve,GA_curve,SA_curve,MIMIC_curve,title="Fitness Value vs Iterations\n(Four Peaks)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsIterations_FourPeaks.png')
FittnessVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Fitness Value vs Problem Size\n(Four Peaks)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsProblemSize_FourPeaks.png')
FevalVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Funtion Evaluations vs Problem Size\n(Four Peaks)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FuntionEvaluationsVsProblemSize_FourPeaks.png')
TimeTakenVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Time Taken vs Problem Size\n(Four Peaks)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTakenVsProblemSize_FourPeaks.png')
TimeTakenVsProblemSize_plotter_log(RHC,GA,SA,MIMIC,title="Time Taken (Log Scale) vs Problem Size\n(Four Peaks)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTaken(LogScale)VsProblemSize_FourPeaks.png')
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
fitness = mlrose.FlipFlop()
RHC,RHC_curve,GA,GA_curve,SA,SA_curve,MIMIC,MIMIC_curve = fuction_runner(fitness,max_attempts=70, SA_schedule=mlrose.GeomDecay(init_temp=1), GA_pop_size=100, GA_mutation_prob=0.2, MIMIC_pop_size = 200, MIMIC_keep_pct=0.5)
FittnessVsIterations_plotter(RHC_curve,GA_curve,SA_curve,MIMIC_curve,title="Fitness Value vs Iterations\n(Flip Flop)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsIterations_FlipFlop.png')
FittnessVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Fitness Value vs Problem Size\n(Flip Flop)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsProblemSize_FlipFlop.png')
FevalVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Funtion Evaluations vs Problem Size\n(Flip Flop)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FuntionEvaluationsVsProblemSize_FlipFlop.png')
TimeTakenVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Time Taken vs Problem Size\n(Flip Flop)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTakenVsProblemSize_FlipFlop.png')
TimeTakenVsProblemSize_plotter_log(RHC,GA,SA,MIMIC,title="Time Taken (Log Scale) vs Problem Size\n(Flip Flop)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTaken(LogScale)VsProblemSize_FlipFlop.png')
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
fitness = mlrose.OneMax()
RHC,RHC_curve,GA,GA_curve,SA,SA_curve,MIMIC,MIMIC_curve = fuction_runner(fitness,max_attempts=100, MIMIC_pop_size = 200, MIMIC_keep_pct=0.5, SA_schedule=mlrose.GeomDecay(init_temp=1))
FittnessVsIterations_plotter(RHC_curve,GA_curve,SA_curve,MIMIC_curve,title="Fitness Value vs Iterations\n(One Max)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsIterations_OneMax.png')
FittnessVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Fitness Value vs Problem Size\n(One Max)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FitnessVsProblemSize_OneMax.png')
FevalVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Funtion Evaluations vs Problem Size\n(One Max)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/FuntionEvaluationsVsProblemSize_OneMax.png')
TimeTakenVsProblemSize_plotter(RHC,GA,SA,MIMIC,title="Time Taken vs Problem Size\n(One Max)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTakenVsProblemSize_OneMax.png')
TimeTakenVsProblemSize_plotter_log(RHC,GA,SA,MIMIC,title="Time Taken (Log Scale) vs Problem Size\n(One Max)",h1 ='C:/Users/sagni/Documents/Personal Files/CS7641/Assignment2/Images/TimeTaken(LogScale)VsProblemSize_OneMax.png')
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90
